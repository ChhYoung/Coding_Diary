# %%
import SVM_Functions as SVMF
import numpy as np
import pandas as pd

# %%
X,y = SVMF.loadData('task2.mat')

# %%
SVMF.plotData(X,y,title='raw data')

# %%
def accu(a,b):
    count = 0
    a = np.array(a)
    b = np.array(b)
    for  i in range(a.shape[0]):
        if a[i] == b[i]:
            count+=1
    return count/a.shape[0]

# %%
acc=[]
for C in [0.01, 0.03, 0.1, 0.3, 1, 3, 10, 30]:
    for sigma in [0.01, 0.03, 0.1, 0.3, 1, 3, 10, 30]:
        model = SVMF.svmTrain_SMO(X,
                y, C , kernelFunction='gaussian',
                K_matrix=SVM_Functions.gaussianKernel(X,sigma))
        y_pred = SVMF.svmPredict(model, X, sigma)
        acc.extend[accu(y_pred,y]
        SVMF.visualizeBoundaryGaussian(X,y,model,sigma)

# %%
acc = []
for i in a:
    bcc = []
    for j in b:
        bcc.extend([1])
    acc.append(bcc)


acc = []
for C in [0.01, 0.03, 0.1, 0.3, 1, 3, 10, 30]:
    bcc = []
    for sigma in [0.01, 0.03, 0.1, 0.3, 1, 3, 10, 30]:
        model = SVMF.svmTrain_SMO(X,
                y, C , kernelFunction='gaussian',
                K_matrix=SVM_Functions.gaussianKernel(X,sigma))
        y_pred = SVMF.svmPredict(model, X, sigma)
        bcc.extend([accu(y_pred,y)])
    acc.append(bcc)
np.array(acc)
        #print('C = {},sigma = {}'.format(C,sigma))
        #print('accuracy = {}'.format(accu(y_pred,y)))
        #SVMF.visualizeBoundaryGaussian(X,y,model,sigma)
# Out:
# GaussianKernel Computing .........................Done( 2.334628213480187s )
#
# Training ............................................Done( 1.747664297219103s )
#
# GaussianKernel Computing .........................Done( 2.1495363359856583s )
#
# Training ....................................................Done( 1.680939187777085s )
#
# GaussianKernel Computing .........................Done( 2.306599385047207s )
#
# Training ...........................................Done( 1.0420159834010292s )
#
# GaussianKernel Computing .........................Done( 2.533516431203452s )
#
# Training ...............................................Done( 1.1627163801614415s )
#
# GaussianKernel Computing .........................Done( 2.481178279040705s )
#
# Training ....................................Done( 0.9502826863080145s )
#
# GaussianKernel Computing .........................Done( 2.4414532576973897s )
#
# Training ........................................Done( 0.9247478815810837s )
#
# ...

# %%
np.array(acc)
# Out:
# array([[0.49763033, 0.49763033, 0.50236967, 0.49763033, 0.81990521,
#         0.8056872 , 0.50236967, 0.49763033],
#        [0.50236967, 0.49763033, 0.49763033, 0.86729858, 0.50236967,
#         0.50236967, 0.49763033, 0.50236967],
#        [0.50236967, 0.49763033, 0.9478673 , 0.86255924, 0.83886256,
#         0.82464455, 0.50236967, 0.50236967],
#        [0.50236967, 0.97630332, 0.9478673 , 0.90521327, 0.87203791,
#         0.71563981, 0.81042654, 0.49763033],
#        [1.        , 0.99526066, 0.9478673 , 0.93364929, 0.90521327,
#         0.84834123, 0.78672986, 0.50236967],
#        [1.        , 1.        , 0.94312796, 0.94312796, 0.92890995,
#         0.87203791, 0.80094787, 0.50236967],
#        [1.        , 1.        , 0.96208531, 0.93838863, 0.91943128,
#         0.90047393, 0.84834123, 0.50236967],
#        [1.        , 1.        , 0.9478673 , 0.94312796, 0.91943128,
#         0.91469194, 0.8436019 , 0.81990521]])

# %%
import numpy as np
import pandas as pd
a=np.array([[0.49763033, 0.49763033, 0.50236967, 0.49763033, 0.81990521,
        0.8056872 , 0.50236967, 0.49763033],
       [0.50236967, 0.49763033, 0.49763033, 0.86729858, 0.50236967,
        0.50236967, 0.49763033, 0.50236967],
       [0.50236967, 0.49763033, 0.9478673 , 0.86255924, 0.83886256,
        0.82464455, 0.50236967, 0.50236967],
       [0.50236967, 0.97630332, 0.9478673 , 0.90521327, 0.87203791,
        0.71563981, 0.81042654, 0.49763033],
       [1.        , 0.99526066, 0.9478673 , 0.93364929, 0.90521327,
        0.84834123, 0.78672986, 0.50236967],
       [1.        , 1.        , 0.94312796, 0.94312796, 0.92890995,
        0.87203791, 0.80094787, 0.50236967],
       [1.        , 1.        , 0.96208531, 0.93838863, 0.91943128,
        0.90047393, 0.84834123, 0.50236967],
       [1.        , 1.        , 0.9478673 , 0.94312796, 0.91943128,
        0.91469194, 0.8436019 , 0.81990521]])

# %%
pd.DataFrame(a).to_csv('m.csv')

# %%
pd.read_csv('m.csv')
# Out:
#   sigma        0.01        0.03         0.1         0.3           1  \
# 0     C
# 1  0.01  0.49763033  0.49763033  0.50236967  0.49763033  0.81990521
# 2  0.03  0.50236967  0.49763033  0.49763033  0.86729858  0.50236967
# 3   0.1  0.50236967  0.49763033   0.9478673  0.86255924  0.83886256
# 4   0.3  0.50236967  0.97630332   0.9478673  0.90521327  0.87203791
# 5     1           1  0.99526066   0.9478673  0.93364929  0.90521327
# 6     3           1           1  0.94312796  0.94312796  0.92890995
# 7    10           1           1  0.96208531  0.93838863  0.91943128
# 8    30           1           1   0.9478673  0.94312796  0.91943128
#
#             3          10          30
# 0
# 1   0.8056872  0.50236967  0.49763033
# 2  0.50236967  0.49763033  0.50236967
# 3  0.82464455  0.50236967  0.50236967
# 4  0.71563981  0.81042654  0.49763033
# 5  0.84834123  0.78672986  0.50236967
# 6  0.87203791  0.80094787  0.50236967
# 7  0.90047393  0.84834123  0.50236967
# ...

# %%
history
# Out:
# import SVM_Functions
# import numpy as np
# import pandas as pd
# X,y = SVM_Functions.loadData('task2.mat')
# X
# X.shape
# y.shape
# y
# SVM_Functions.plotData(X,y,title='raw data')
# import SVM_Functions as SVM
# import numpy as np
# import pandas as pd
# import SVM_Functions as SVMF
# import numpy as np
# import pandas as pd
# X,y = SVMF.loadData('task2.mat')
# SVMF.plotData(X,y,title='raw data')
# a = [0.01, 0.03, 0.1, 0.3, 1, 3, 10, 30]
# np.array(a).shape[0]
# def accu(a,b):
#     count = 0
#     a = np.array(a)
#     b = np.array(b)
#     for  i in a.shape[0]:
#         if a[i] = b[i]:
#             count+=1
#     return count/a.shape[0]
# a = [0.01, 0.03, 0.1, 0.3, 1, 3, 10, 30]
# b = [0.01, 0.03, 0.1, 0.3, 1, 3, 10, 30]
# accu(a,b)
# def accu(a,b):
#     count = 0
#     a = np.array(a)
#     b = np.array(b)
#     for  i in a.shape[0]:
#         if a[i] == b[i]:
#             count+=1
#     return count/a.shape[0]
# a = [0.01, 0.03, 0.1, 0.3, 1, 3, 10, 30]
# ...
